# %% [markdown]
# # Agenter Quickstart
#
# This notebook demonstrates the core features of Agenter - the backend-agnostic SDK for autonomous coding agents.

# %% [markdown]
# ## Setup
#
# ```bash
# # Install core agenter with all backends and adapters used in this notebook
# pip install agenter[codex,claude-code,langgraph,pydantic-ai]
#
# # Set the API key for your LLM provider
# export ANTHROPIC_API_KEY="your-api-key"  # Anthropic
# export OPENAI_API_KEY="your-api-key"     # OpenAI
#
# # Pick your backend (defaults to "anthropic-sdk")
# export ACA_DEFAULT_BACKEND="codex"  # Options: anthropic-sdk, claude-code, codex, openhands
# ```

# %%
import tempfile
from pathlib import Path

from agenter import AutonomousCodingAgent, CodingRequest, configure_logging

# Silence verbose debug logs for cleaner notebook output
configure_logging(level="WARNING")

# Use configure_logging(level="DEBUG") to see all internal logs

# %% [markdown]
# ## 1. Basic Usage
#
# The simplest way to use Agenter: give it a prompt and a directory.

# %%
# Create a temporary workspace
workspace_1 = tempfile.mkdtemp(prefix="agenter_demo_")

agent = AutonomousCodingAgent()
result = await agent.execute(
    CodingRequest(
        prompt="Create a minimal Python function that calculates Fibonacci numbers.",
        cwd=workspace_1,
    )
)
result
# Out:
# CodingResult(status=<CodingStatus.COMPLETED: 'completed'>, files={'fibonacci.py': 'def fibonacci(n):\n    """Calculate the nth Fibonacci number.\n    \n    Args:\n        n (int): The position in the Fibonacci sequence (0-indexed)\n        \n    Returns:\n        int: The nth Fibonacci number\n    """\n    if n <= 1:\n        return n\n    return fibonacci(n - 1) + fibonacci(n - 2)\n\n\n# Example usage\nif __name__ == "__main__":\n    # Print first 10 Fibonacci numbers\n    for i in range(10):\n        print(f"F({i}) = {fibonacci(i)}")'}, summary='Task completed successfully', iterations=1, total_tokens=2669, total_input_tokens=0, total_output_tokens=0, total_cost_usd=0.012879, total_duration_seconds=8.463375209015794, exceeded_limit=None, exceeded_values=None, output=None, trace_dir=None)

# %% [markdown]
# ## 2. Streaming Events
#
# **Built-in display**: Use `verbosity=Verbosity.NORMAL` for Rich-formatted output.
#
# **Custom event handling**: Process events exactly how you want (for example, for your custom UI or logging setup).

# %%
from agenter import Verbosity
from agenter.data_models import CodingEventType
from agenter.data_models.messages import ToolCallMessage

workspace_2 = tempfile.mkdtemp(prefix="agenter_stream_")

agent = AutonomousCodingAgent()
request = CodingRequest(
    prompt="Create a calculator module with add, subtract, multiply, divide.",
    cwd=workspace_2,
)

tools_used = []
async for event in agent.stream_execute(request, verbosity=Verbosity.NORMAL):
    if event.type == CodingEventType.BACKEND_MESSAGE and isinstance(event.message, ToolCallMessage):
        tools_used.append(event.message.tool_name)

print(f"List of tool used: {tools_used}")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╔════════════════════════════════════════════════════ Agenter ════════════════════════════════════════════════════╗
# ║ Working directory: /var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_stream_o3hv_2bl                     ║
# ║ Model: us.anthropic.claude-sonnet-4-20250514-v1:0                                                               ║
# ╚═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ▶ Iteration 1
# ╭─────────────────────────────────────────────────── 📝 Prompt ───────────────────────────────────────────────────╮
# │ Create a calculator module with add, subtract, multiply, divide.                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── 📨 Response (694 tokens) ────────────────────────────────────────────╮
# │ I'll create a calculator module with the four basic arithmetic operations. Let me start by creating the         │
# │ calculator module file.                                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 🔧 Tool ✓ ───────────────────────────────────────────────────╮
# │ write_file calculator.py                                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── 📨 Response (461 tokens) ────────────────────────────────────────────╮
# │ Now let me create a simple test file to demonstrate the usage of the calculator module:                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 🔧 Tool ✓ ───────────────────────────────────────────────────╮
# │ write_file test_calculator.py                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── 📨 Response (637 tokens) ────────────────────────────────────────────╮
# │ Let me also create a README file to document how to use the calculator module:                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── 🔧 Tool ✓ ───────────────────────────────────────────────────╮
# │ write_file README.md                                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── 📨 Response (377 tokens) ────────────────────────────────────────────╮
# │ Perfect! I've created a complete calculator module with the following components:                               │
# │                                                                                                                 │
# │ ## Files Created:                                                                                               │
# │                                                                                                                 │
# │ 1. **`calculator.py`** - The main calculator module containing:                                                 │
# │    - `add(a, b)` - Addition function                                                                            │
# │    - `subtract(a, b)` - Subtraction function                                                                    │
# │    - `multiply(a, b)` - Multiplication function                                                                 │
# │    - `divide(a, b)` - Division function with zero-division protection                                           │
# │    - Comprehensive docstrings for each function                                                                 │
# │    - Built-in test examples when run directly                                                                   │
# │                                                                                                                 │
# │ 2. **`test_calculator.py`** - A test fi                                                                         │
# │ ... (1,560 chars total)                                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── ✓ Validation ──────────────────────────────────────────────────╮
# │ All checks passed                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╔════════════════════════════════════════════════════ Summary ════════════════════════════════════════════════════╗
# ║   Status:            ✅ Completed                                                                               ║
# ║   Iterations:        1                                                                                          ║
# ║   Tokens:            9,979                                                                                      ║
# ║   Duration:          26.5s                                                                                      ║
# ║   Files modified:    3                                                                                          ║
# ║                        • calculator.py                                                                          ║
# ║                        • test_calculator.py                                                                     ║
# ║                        • README.md                                                                              ║
# ╚═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
# List of tool used: ['write_file', 'write_file', 'write_file']

# %% [markdown]
# ## 3. Structured Outputs
#
# Get typed, validated outputs using Pydantic models.

# %%
from pydantic import BaseModel


class CodeAnalysis(BaseModel):
    """Structured output for code analysis."""

    summary: str
    issues: list[str]
    suggestions: list[str]
    complexity_score: int  # 1-10


workspace_3 = tempfile.mkdtemp(prefix="agenter_structured_")

# Create a file to analyze
Path(workspace_3, "example.py").write_text("""
def process_data(data):
    result = []
    for item in data:
        if item > 0:
            for i in range(item):
                if i % 2 == 0:
                    result.append(i * item)
    return result
""")

agent = AutonomousCodingAgent()
result = await agent.execute(
    CodingRequest(
        prompt="Analyze the code in example.py for complexity and potential issues.",
        cwd=workspace_3,
        output_type=CodeAnalysis,  # With structured output
    )
)

analysis: CodeAnalysis = result.output

print(f"Summary: {analysis.summary}")
print(f"Complexity: {analysis.complexity_score}/10")
print(f"Issues: {analysis.issues}")
print(f"Suggestions: {analysis.suggestions}")
# Out:
# Summary: The code defines a function `process_data` that processes a list of numbers by iterating through positive values and generating even-indexed multiples. The function has moderate complexity due to nested loops and conditional logic.
# Complexity: 6/10
# Issues: ["No input validation - function doesn't check if 'data' is iterable or contains valid numeric types", "No documentation or docstring explaining the function's purpose and expected behavior", "Variable name 'item' is not descriptive of what the data represents", 'Potential performance issue with nested loops for large datasets', 'No handling of edge cases like empty lists or non-numeric values', 'The algorithm logic may not be immediately clear to other developers']
# Suggestions: ["Add input validation to ensure 'data' is a list/iterable of numbers", 'Add a comprehensive docstring explaining parameters, return value, and behavior', "Use more descriptive variable names (e.g., 'number' instead of 'item')", 'Consider using list comprehension for better performance and readability', 'Add type hints for better code documentation', 'Consider adding error handling for non-numeric values', 'Add unit tests to verify the function behaves correctly with various inputs', 'Example refactor: `def process_data(data: List[int]) -> List[int]:`']

# %% [markdown]
# ## 4. Switching Backends
#
# Switch between backends without changing your code.

# %%
workspace_4 = tempfile.mkdtemp(prefix="agenter_backends_")

task = CodingRequest(
    prompt="Create a hello.py that prints 'Hello, World!'",
    cwd=workspace_4,
)

# Same task, different backends - each uses its own default model
for backend in ["anthropic-sdk", "codex"]:
    agent = AutonomousCodingAgent(backend=backend)
    result = await agent.execute(task)
    print(f"{backend}: {result.status} (${result.total_cost_usd:.4f})")
# Out:
# anthropic-sdk: CodingStatus.COMPLETED ($0.0085)
# codex: CodingStatus.COMPLETED ($0.0018)

# %% [markdown]
# ## 5. Framework Adapters
#
# Adapters **subclass framework base classes** to set up tracing and all framework features automatically.
#
# - **LangGraph**: `create_coding_node()` returns `RunnableLambda` → LangSmith tracing works when `LANGSMITH_API_KEY` is set
# - **PydanticAI**: `CodingAgent` subclasses `pydantic_ai.Agent` → Logfire tracing works automatically

# %%
# PydanticAI adapter - CodingAgent IS-A pydantic_ai.Agent
from agenter.adapters.pydantic_ai import CodingAgent

workspace_5 = tempfile.mkdtemp(prefix="agenter_pydantic_")

# CodingAgent subclasses pydantic_ai.Agent and overrides .run()
# Using codex backend (OpenAI models)
agent = CodingAgent(cwd=workspace_5, backend="codex")

result = await agent.run("Create a hello world script.")

print(f"Status: {result.status}")
print(f"Summary: {result.summary}")
# Out:
# Status: CodingStatus.COMPLETED
# Summary: Task completed successfully

# %%
# LangGraph adapter - returns RunnableLambda for LangSmith tracing
from agenter.adapters.langgraph import create_coding_node

workspace_6 = tempfile.mkdtemp(prefix="agenter_langgraph_")

# create_coding_node returns RunnableLambda (langchain base class)
# Using anthropic-sdk
coding_node = create_coding_node(cwd=workspace_6, backend="anthropic-sdk")

# Use ainvoke() - LangSmith traces automatically
state = {"prompt": "Create a utility function to format dates."}
result_state = await coding_node.ainvoke(state)

print(f"Status: {result_state['coding_result']['status']}")
print(f"Summary: {result_state['coding_result']['summary']}")
# Out:
# Status: CodingStatus.COMPLETED
# Summary: Task completed successfully

# %% [markdown]
# ## Cleanup

# %%
import shutil

for ws in [workspace_1, workspace_2, workspace_3, workspace_4, workspace_5, workspace_6]:
    try:
        shutil.rmtree(ws)
        print(f"Dir '{ws}' cleaned up.")
    except Exception:
        pass
# Out:
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_demo_zid0wpii' cleaned up.
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_stream_o3hv_2bl' cleaned up.
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_structured_52rba6gm' cleaned up.
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_backends_0uulqg4g' cleaned up.
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_pydantic_7aqiorpo' cleaned up.
# Dir '/var/folders/0f/1wtyzkj508nbh_hny1k3rrbm0000gn/T/agenter_langgraph_d62uh344' cleaned up.
